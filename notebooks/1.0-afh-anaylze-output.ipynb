# %%
import pandas as pd
import numpy as np
import os

from permit_data_extraction.config import PROCESSED_DATA_DIR
# Out:
# 2025-08-05 15:13:36.426 | INFO     | permit_data_extraction.config:<module>:11 - PROJ_ROOT path is: /home/afhubbard/permit_data_extraction

# %%
FILE_PATH = os.path.join(PROCESSED_DATA_DIR, 'permit_data_extracted.xlsx')

# %%
df = pd.read_excel(FILE_PATH)

# %%
df.count() / len(df)
# Out:
# Filename                                                               1.000000
# Status                                                                 1.000000
# Facility Name                                                          0.998932
# Facility Address                                                       0.980769
# Facility City                                                          0.998932
# Facility State Abbreviation                                            1.000000
# Facility Zip Code                                                      0.977564
# Facility County                                                        0.426282
# NAICS Code                                                             0.565171
# Operating Hours                                                        0.282051
# Industry Description                                                   0.974359
# Permit Number                                                          0.985043
# Issuance Date                                                          0.998932
# Expiration Date                                                        0.955128
# Regulatory Authority                                                   0.998932
# Primary Applicable Regulations (e.g., Title V, PSD, NESHAP Subpart)    1.000000
# Unit ID                                                                0.996795
# Unit Description                                                       0.993590
# Unit Make                                                              0.460470
# Unit Model                                                             0.377137
# Year of Manufacture                                                    0.360043
# Unit Type                                                              0.992521
# Pollutants                                                             0.942308
# Emission Limits                                                        0.856838
# Control Device(s)                                                      0.500000
# Capacity Value                                                         0.685897
# Capacity Unit                                                          0.685897
# Fuel Type                                                              0.480769
# Rated Efficiency                                                       0.106838
# dtype: float64
