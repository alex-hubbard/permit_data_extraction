# %%
import pandas as pd
import numpy as np
import os

from permit_data_extraction.config import PROCESSED_DATA_DIR

# %%
FILE_PATH = os.path.join(PROCESSED_DATA_DIR, 'permit_data_extracted.xlsx')

# %%
df = pd.read_excel(FILE_PATH)

# %%
df.count() / len(df)
# Out:
# Filename                                                               1.000000
# Status                                                                 1.000000
# Facility Name                                                          0.999305
# Facility Address                                                       0.999305
# Facility City                                                          0.999305
# Facility State                                                         1.000000
# Facility Zip Code                                                      0.937413
# Facility County                                                        0.431154
# NAICS Code                                                             0.509736
# Operating Hours                                                        0.036857
# Industry Description                                                   0.773296
# Permit Number                                                          0.807371
# Issuance Date                                                          0.999305
# Expiration Date                                                        0.920723
# Regulatory Authority                                                   1.000000
# Primary Applicable Regulations (e.g., Title V, PSD, NESHAP Subpart)    0.997914
# Unit ID                                                                0.994437
# Unit Description                                                       0.992350
# Unit Make                                                              0.361613
# Unit Model                                                             0.288595
# Unit Type                                                              0.885257
# Pollutants                                                             0.751739
# Emission Limits                                                        0.635605
# Control Device(s)                                                      0.409597
# Capacity                                                               0.612656
# Fuel Type                                                              0.442976
# Rated Efficiency                                                       0.032684
# dtype: float64
