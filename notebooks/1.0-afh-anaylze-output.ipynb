# %%
import pandas as pd
import numpy as np
import os

from permit_data_extraction.config import PROCESSED_DATA_DIR
# Out:
# 2026-02-06 15:59:46.767 | INFO     | permit_data_extraction.config:<module>:11 - PROJ_ROOT path is: /home/afhubbard/permit_data_extraction

# %%
FILE_PATH = os.path.join(PROCESSED_DATA_DIR, 'permit_data_extracted.xlsx')

# %%
df = pd.read_excel(FILE_PATH)

# %%
df.count() / len(df)
# Out:
# Filename                                                               1.000000
# Status                                                                 1.000000
# Processing Date                                                        1.000000
# Facility Name                                                          0.999761
# Facility Address                                                       0.881656
# Facility City                                                          0.939798
# Facility State Abbreviation                                            0.982250
# Facility Zip Code                                                      0.742436
# Facility County                                                        0.697703
# NAICS Code                                                             0.614803
# Operating Hours                                                        0.077657
# Industry Description                                                   0.748800
# Permit Number                                                          0.906984
# Issuance Date                                                          0.713024
# Expiration Date                                                        0.622970
# Regulatory Authority                                                   0.961760
# Primary Applicable Regulations (e.g., Title V, PSD, NESHAP Subpart)    0.268472
# Unit ID                                                                0.943753
# Unit Description                                                       0.948020
# Unit Quantity                                                          0.171041
# Unit Make                                                              0.209189
# Unit Model                                                             0.168613
# Year of Manufacture                                                    0.122648
# Unit Type                                                              0.581566
# Pollutants                                                             0.587305
# Emission Limits                                                        0.433167
# Control Device(s)                                                      0.318208
# Capacity Value                                                         0.505803
# Capacity Unit                                                          0.438170
# Fuel Type                                                              0.432560
# Rated Efficiency                                                       0.008332
# Annual Run Hours                                                       0.112421
# Generation Capacity                                                    0.046039
# Spec Sheet Link                                                        0.000000
# Model Used                                                             0.967370
# Duplicate Equipment Documents                                          0.996965
# Latest Facility Filename                                               0.996965
# dtype: float64
